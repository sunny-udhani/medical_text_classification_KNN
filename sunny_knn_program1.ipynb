# %%
import numpy as np
import pandas as pd
import scipy.sparse as sp
from numpy.linalg import norm
from collections import Counter, defaultdict
from scipy.sparse import csr_matrix
from nltk.corpus import stopwords
import string

# %%
df = pd.read_csv(
    filepath_or_buffer='data/train.dat', 
    header=None, 
    sep='\n')
df = pd.DataFrame(df[0].str.split('\t', 1).tolist())
statements = df[1]
classes = df[0]
print(statements)
# Out:
# 0        Catheterization laboratory events and hospital...
# 1        Renal abscess in children. Three cases of rena...
# 2        Hyperplastic polyps seen at sigmoidoscopy are ...
# 3        Subclavian artery to innominate vein fistula a...
# 4        Effect of local inhibition of gamma-aminobutyr...
# 5        Infection during chronic epidural catheterizat...
# 6        Mediastinal tracheostomy using a pectoralis ma...
# 7        Tumefactive fibroinflammatory lesion of the ex...
# 8        Multiple representations contribute to body kn...
# 9        Increasing asthma prevalence in a rural New Ze...
# 10       Usefulness of the automatic implantable cardio...
# 11       Stress-related mucosal damage: review of drug ...
# 12       A biphasic pattern of anti-pre-S responses in ...
# 13       A controlled trial comparing vidarabine with a...
# 14       Pentostatin induces durable remissions in hair...
# 15       Cytologic features of poorly differentiated 'i...
# 16       Cutaneous manifestations of multiple myeloma. ...
# 17       Steal-prone coronary anatomy and myocardial is...
# 18       Ewing's sarcoma. Radiotherapy versus surgery f...
# 19       Tethered cord syndrome from a choristoma of mu...
# 20       Immunohistochemical detection of P-glycoprotei...
# 21       Acute phase reactants and risk of bacterial me...
# 22       Follicular thyroid cancer treated at the Mayo ...
# 23       Hypertension as a risk factor for epilepsy aft...
# 24       Mortality in acute stroke with atrial fibrilla...
# 25       Renal replacement treatment for diabetic patie...
# 26       Acute urinary retention secondary to Herpes si...
# 27       Indications for computed tomography in childre...
# 28       Lexical organization of nouns and verbs in the...
# 29       Vitamin B6 in the treatment of the premenstrua...
#                                ...
# 14408    SPECT imaging of pediatric brain tumor with he...
# 14409    The supraspinal anxiolytic effect of baclofen ...
# 14410    Sixty consecutive breast reconstructions with ...
# 14411    Recurrent transient ischemic attacks and strok...
# 14412    Primary defect in alpha-adrenergic responsiven...
# 14413    The Van Nes tibial rotationplasty. A functiona...
# 14414    Disposition of 5-aminosalicylic acid by olsala...
# 14415    Treatment of angiomas with sclerosing injectio...
# 14416    Cystic medionecrosis of the coronary arteries ...
# 14417    Natural history of progressive ischemic stroke...
# 14418    Nasal valve malfunction resulting from resecti...
# 14419    A blood-liquid interface for prolonged extraco...
# 14420    Genetic mechanisms of tumor suppression by the...
# 14421    The human immunodeficiency virus type 1 polyad...
# 14422    Use of a computerized closed-loop sodium nitro...
# 14423    Fetal choroid plexus cysts: a prospective stud...
# 14424    Pyloric deformation from peptic disease. Radio...
# 14425    Scoliosis in trisomy 18. Patients with trisomy...
# 14426    Single-stage laryngotracheal reconstruction. T...
# 14427    Giant-cell arteritis of the uterus with associ...
# 14428    The determinants and prognostic significance o...
# 14429    Primary de novo adenocarcinoma of the colon me...
# 14430    Extensive peripheral retinectomy combined with...
# 14431    Early diagnosis and survival of ruptured abdom...
# 14432    Embolization with particles in thoracic intram...
# 14433    Quadricuspid aortic valve and aortic regurgita...
# 14434    Mammographic measurements before and after aug...
# 14435    Use of leukocyte-depleted platelet concentrate...
# 14436    Complications of Tenckhoff catheters post remo...
# 14437    Fatal or severely disabling cerebral infarctio...
# Name: 1, Length: 14438, dtype: object

# %%
def cmer(name, c=3):
    r""" Given a name and parameter c, return the vector of c-mers associated with the name
    """
    name = name.lower()
    s=set(stopwords.words('english'))
    table = str.maketrans('', '', string.punctuation)
    aaj= list(filter(lambda w: not w in s,name.split()))
    stripped = [w.translate(table) for w in aaj]
#     print(stripped)
    v = []
    
#   find substrings of lenght "c" from every position in the string
    for i in range(0, len(stripped) - c + 1):
        v.append(stripped[i:i+c])
    
#     print(v)
    return v

# %%
def build_matrix(docs):
    r""" Build sparse matrix from a list of documents,
    each of which is a list of word/terms in the document.  
    """
    print(docs)
    nrows = len(docs)
    idx = {}
    tid = 0
    nnz = 0
    for d in docs:
        nnz += len(set(d))
        for w in d:
            if w not in idx:
                idx[w] = tid
                tid += 1
    ncols = len(idx)
        
    # set up memory
    ind = np.zeros(nnz, dtype=np.int)
    val = np.zeros(nnz, dtype=np.double)
    ptr = np.zeros(nrows+1, dtype=np.int)
    i = 0  # document ID / row counter
    n = 0  # non-zero counter
    # transfer values
    for d in docs:
        cnt = Counter(d)
        keys = list(k for k,_ in cnt.most_common())
        l = len(keys)
        for j,k in enumerate(keys):
            print(j)
            print(k)
            ind[j+n] = idx[k]
            val[j+n] = cnt[k]
        ptr[i+1] = ptr[i] + l
        n += l
        i += 1
            
#     print(ind[:20])        
    mat = csr_matrix((val, ind, ptr), shape=(nrows, ncols), dtype=np.double)
    mat.sort_indices()
    
    return mat

def csr_info(mat, name="", non_empy=False):
    r""" Print out info about this CSR matrix. If non_empy, 
    report number of non-empty rows and cols as well
    """
    if non_empy:
        print("%s [nrows %d (%d non-empty), ncols %d (%d non-empty), nnz %d]" % (
                name, mat.shape[0], 
                sum(1 if mat.indptr[i+1] > mat.indptr[i] else 0 
                for i in range(mat.shape[0])), 
                mat.shape[1], len(np.unique(mat.indices)), 
                len(mat.data)))
    else:
        print( "%s [nrows %d, ncols %d, nnz %d]" % (name, 
                mat.shape[0], mat.shape[1], len(mat.data)) )

def csr_l2normalize(mat, copy=False, **kargs):
    r""" Normalize the rows of a CSR matrix by their L-2 norm. 
    If copy is True, returns a copy of the normalized matrix.
    """
    if copy is True:
        mat = mat.copy()
    nrows = mat.shape[0]
    nnz = mat.nnz
    ind, val, ptr = mat.indices, mat.data, mat.indptr
    # normalize
    for i in range(nrows):
        rsum = 0.0    
        for j in range(ptr[i], ptr[i+1]):
            rsum += val[j]**2
        if rsum == 0.0:
            continue  # do not normalize empty rows
        rsum = 1.0/np.sqrt(rsum)
        for j in range(ptr[i], ptr[i+1]):
            val[j] *= rsum
            
    if copy is True:
        return mat
        
def namesToMatrix(names, c):
#     print(names)
    docs = [cmer(n, c) for n in names]
    return build_matrix(docs)

# %%
mat = namesToMatrix(statements,5)
csr_info(mat,'For c=' + str(5))
# Out:
# [[['catheterization', 'laboratory', 'events', 'hospital', 'outcome'], ['laboratory', 'events', 'hospital', 'outcome', 'direct'], ['events', 'hospital', 'outcome', 'direct', 'angioplasty'], ['hospital', 'outcome', 'direct', 'angioplasty', 'acute'], ['outcome', 'direct', 'angioplasty', 'acute', 'myocardial'], ['direct', 'angioplasty', 'acute', 'myocardial', 'infarction'], ['angioplasty', 'acute', 'myocardial', 'infarction', 'assess'], ['acute', 'myocardial', 'infarction', 'assess', 'safety'], ['myocardial', 'infarction', 'assess', 'safety', 'direct'], ['infarction', 'assess', 'safety', 'direct', 'infarct'], ['assess', 'safety', 'direct', 'infarct', 'angioplasty'], ['safety', 'direct', 'infarct', 'angioplasty', 'without'], ['direct', 'infarct', 'angioplasty', 'without', 'antecedent'], ['infarct', 'angioplasty', 'without', 'antecedent', 'thrombolytic'], ['angioplasty', 'without', 'antecedent', 'thrombolytic', 'therapy'], ['without', 'antecedent', 'thrombolytic', 'therapy', 'catheterization'], ['antecedent', 'thrombolytic', 'therapy', 'catheterization', 'laboratory'], ['thrombolytic', 'therapy', 'catheterization', 'laboratory', 'hospital'], ['therapy', 'catheterization', 'laboratory', 'hospital', 'events'], ['catheterization', 'laboratory', 'hospital', 'events', 'assessed'], ['laboratory', 'hospital', 'events', 'assessed', 'consecutively'], ['hospital', 'events', 'assessed', 'consecutively', 'treated'], ['events', 'assessed', 'consecutively', 'treated', 'patients'], ['assessed', 'consecutively', 'treated', 'patients', 'infarctions'], ['consecutively', 'treated', 'patients', 'infarctions', 'involving'], ['treated', 'patients', 'infarctions', 'involving', 'left'], ['patients', 'infarctions', 'involving', 'left', 'anterior'], ['infarctions', 'involving', 'left', 'anterior', 'descending'], ['involving', 'left', 'anterior', 'descending', 'n'], ['left', 'anterior', 'descending', 'n', ''], ['anterior', 'descending', 'n', '', '100'], ['descending', 'n', '', '100', 'patients'], ['n', '', '100', 'patients', 'right'], ['', '100', 'patients', 'right', 'n'], ['100', 'patients', 'right', 'n', ''], ['patients', 'right', 'n', '', '100'], ['right', 'n', '', '100', 'circumflex'], ['n', '', '100', 'circumflex', 'n'], ['', '100', 'circumflex', 'n', ''], ['100', 'circumflex', 'n', '', '50'], ['circumflex', 'n', '', '50', 'coronary'], ['n', '', '50', 'coronary', 'arteries'], ['', '50', 'coronary', 'arteries', 'groups'], ['50', 'coronary', 'arteries', 'groups', 'patients'], ['coronary', 'arteries', 'groups', 'patients', 'similar'], ['arteries', 'groups', 'patients', 'similar', 'age'], ['groups', 'patients', 'similar', 'age', 'left'], ['patients', 'similar', 'age', 'left', 'anterior'], ['similar', 'age', 'left', 'anterior', 'descending'], ['age', 'left', 'anterior', 'descending', 'coronary'], ['left', 'anterior', 'descending', 'coronary', 'artery'], ['anterior', 'descending', 'coronary', 'artery', '59'], ['descending', 'coronary', 'artery', '59', 'years'], ['coronary', 'artery', '59', 'years', 'right'], ['artery', '59', 'years', 'right', 'coronary'], ['59', 'years', 'right', 'coronary', 'artery'], ['years', 'right', 'coronary', 'artery', '58'], ['right', 'coronary', 'artery', '58', 'years'], ['coronary', 'artery', '58', 'years', 'circumflex'], ['artery', '58', 'years', 'circumflex', 'coronary'], ['58', 'years', 'circumflex', 'coronary', 'artery'], ['years', 'circumflex', 'coronary', 'artery', '62'], ['circumflex', 'coronary', 'artery', '62', 'years'], ['coronary', 'artery', '62', 'years', 'patients'], ['artery', '62', 'years', 'patients', 'multivessel'], ['62', 'years', 'patients', 'multivessel', 'disease'], ['years', 'patients', 'multivessel', 'disease', 'left'], ['patients', 'multivessel', 'disease', 'left', 'anterior'], ['multivessel', 'disease', 'left', 'anterior', 'descending'], ['disease', 'left', 'anterior', 'descending', 'coronary'], ['left', 'anterior', 'descending', 'coronary', 'artery'], ['anterior', 'descending', 'coronary', 'artery', '55'], [ ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-cf4c1440d2b6> in <module>()
# ----> 1 mat = namesToMatrix(statements,5)
#       2 csr_info(mat,'For c=' + str(5))
#
# <ipython-input-41-50a713c28e64> in namesToMatrix(names, c)
#      83 #     print(names)
#      84     docs = [cmer(n, c) for n in names]
# ---> 85     return build_matrix(docs)
#
# <ipython-input-41-50a713c28e64> in build_matrix(docs)
#       9     nnz = 0
#      10     for d in docs:
# ---> 11         nnz += len(set(d))
#      12         for w in d:
#      13             if w not in idx:
#
# TypeError: unhashable type: 'list'
